# %% [markdown]
# Assignment-4

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# 1. Download the dataset: Dataset
# https://drive.google.com/file/d/1Z21e5HOZZR81sC_dnfCDPDMEzs-w8ysr/view
# #import urllib.request
# #urllib.request.urlretrieve("chttps://drive.google.com/file/d/1Z21e5HOZZR81sC_dnfCDPDMEzs-w8ysr/view", "Mall_customer.csv")
# OR in COLAB
# #!wget https://drive.google.com/file/d/1Z21e5HOZZR81sC_dnfCDPDMEzs-w8ysr/view -O Mall_customer.csv

# %% [markdown]
# 2. Load the dataset into the tool.

# %%
df = pd.read_csv('Mall_Customers.csv')
df.info
# Out:
# <bound method DataFrame.info of      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df.describe(include='all')
# Out:
#         CustomerID  Gender         Age  Annual Income (k$)  \
# count   200.000000     200  200.000000          200.000000
# unique         NaN       2         NaN                 NaN
# top            NaN  Female         NaN                 NaN
# freq           NaN     112         NaN                 NaN
# mean    100.500000     NaN   38.850000           60.560000
# std      57.879185     NaN   13.969007           26.264721
# min       1.000000     NaN   18.000000           15.000000
# 25%      50.750000     NaN   28.750000           41.500000
# 50%     100.500000     NaN   36.000000           61.500000
# 75%     150.250000     NaN   49.000000           78.000000
# max     200.000000     NaN   70.000000          137.000000
#
#         Spending Score (1-100)
# count               200.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                 50.200000
# std                  25.823522
# ...

# %% [markdown]
# 3. Perform Below Visualizations.
#     ∙ Univariate Analysis

# %%
sns.displot(df['Gender'])

# %%
sns.displot(df['Age'])

# %% [markdown]
#     ∙ Bi- Variate Analysis

# %%
sns.lineplot(x=df['Gender'],y=df['Age'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.lineplot(x=df['Age'],y=df['Annual Income (k$)'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
sns.pairplot(df)

# %% [markdown]
#     ∙ Multi-Variate Analysis

# %%
sns.scatterplot(x=df['Age'],y=df['Annual Income (k$)'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual Income (k$)'>

# %%
df.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 4. Perform descriptive statistics on the dataset.

# %%
df.mean()
# Out:
# <ipython-input-16-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-17-6d467abf240d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
df.mode()
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Female  32.0                54.0                    42.0
# 1             2     NaN   NaN                78.0                     NaN
# 2             3     NaN   NaN                 NaN                     NaN
# 3             4     NaN   NaN                 NaN                     NaN
# 4             5     NaN   NaN                 NaN                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN   NaN                 NaN                     NaN
# 196         197     NaN   NaN                 NaN                     NaN
# 197         198     NaN   NaN                 NaN                     NaN
# 198         199     NaN   NaN                 NaN                     NaN
# 199         200     NaN   NaN                 NaN                     NaN
#
# [200 rows x 5 columns]

# %%
df.var()
# Out:
# <ipython-input-19-28ded241fd7c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# CustomerID                3350.000000
# Age                        195.133166
# Annual Income (k$)         689.835578
# Spending Score (1-100)     666.854271
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-20-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# CustomerID                57.879185
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %% [markdown]
# 5. Check for Missing values and deal with them.

# %%
df.isnull().any()
# Out:
# CustomerID                False
# Gender                    False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %% [markdown]
# 6. Find the outliers and replace them outliers

# %% [markdown]
# 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
df['Gender'] = label.fit_transform(df['Gender'])
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %% [markdown]
# 8. Scaling the data

# %% [markdown]
# 9. Perform any of the clustering algorithms

# %%
x = df.iloc[:, [3, 4]].values
print(x.shape)
# Out:
# (200, 2)

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

# %%
plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'miser')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'general')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'cyan', label = 'target')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'magenta', label = 'spendthrift')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'careful')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'black' , label = 'centeroid')
plt.style.use('fivethirtyeight')
plt.title('K Means Clustering', fontsize = 20)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.grid()
plt.show()
